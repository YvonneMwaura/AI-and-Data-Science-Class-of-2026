# %% [markdown]
# <a href="https://colab.research.google.com/github/YvonneMwaura/AI-and-Data-Science-Class-of-2026/blob/main/Assignment%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=input('number 1:')
b=input('number 2:')
a=int(a)
b=int(b)
c=a+b
d=b-a
e=a*b
f= a/b
print(f'answers to:Addition={c}_Subtraction={d}_Multiplication={e}_Division={f}')
# Out:
# number 1:26
# number 2:74
# answers to:Addition=100_Subtraction=48_Multiplication=1924_Division=0.35135135135135137

# %%
Username=input("Enter your full names:")
Age =input("Enter your current age:")
Course=input("Enter the name of the course you are applying for:")
print(f'Welcome {Username}. You are {Age} years old. You are currently applying for {Course}')
# Out:
# Enter your full names:Yvonne
# Enter your current age:18
# Enter the name of the course you are applying for:Beauty
# Welcome Yvonne. You are 18 years old. You are currently applying for Beauty
